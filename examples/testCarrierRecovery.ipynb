# %%
import sys
import os

sys.path.append(os.path.abspath( \
    os.path.join(r'/home/silas/Documents/GitHub/CoherentOptics/algorithms/')))

from carrierRecovery import fourthPower, viterbiCPR, laplaceViterbiCPR

# %% [markdown]
# # Obtenha curvas de desempenho para o algoritmo Viterbi & Viterbi

# %% [markdown]
# Este notebook tem por objetivo gerar curvas de desempenho do tipo (BER vs SNR) para a análise do algoritmo Viterbi & Viterbi e sua respectiva variante implementada a partir da distribuição de laplace.

# %%
import matplotlib.pyplot as plt
import numpy as np

from optic.dsp.core import pulseShape, firFilter, decimate, pnorm
from optic.models.devices import pdmCoherentReceiver, basicLaserModel
from optic.models.channels import awgn
from optic.models.tx import simpleWDMTx
from optic.utils import parameters
from optic.comm.metrics import fastBERcalc
from optic.comm.modulation import grayMapping
from optic.plot import pconst

# %% [markdown]
# ## BER vs SNR (laser line width)

# %% [markdown]
# - Variação da largura de linha do transmissor e oscilador local
# - Variação da SNR do canal AWGN
# - Valores fixos para o comprimento da janela e parâmetro de dispersão $\alpha$

# %%
path = '/home/silas/Documents/GitHub/CoherentOptics/data/'

lineWidth = [100e3, 250e3, 350e3, 450e3, 550e3] # laser linewidth in Hz
snrValues = np.arange(10, 21) # snr awgn channel in dB

SNR = np.zeros((2, len(lineWidth), len(snrValues)))
BER = np.zeros((2, len(lineWidth), len(snrValues)))
SER = np.zeros((2, len(lineWidth), len(snrValues)))

for indAlg, alg in enumerate(['viterbi', 'viterbiLaplace']):
    for indlw, lw in enumerate(lineWidth):
        for indSNR, snrdB in enumerate(snrValues):

            # Transmitter parameters:
            paramTx = parameters()
            paramTx.M = 16                  # order of the modulation format
            paramTx.constType = 'qam'       # modulation scheme
            paramTx.Rs  = 32e9              # symbol rate [baud]
            paramTx.SpS = 16                # samples per symbol
            paramTx.pulse = 'rrc'           # pulse shaping filter
            paramTx.Ntaps = 4096            # number of pulse shaping filter coefficients
            paramTx.alphaRRC = 0.01         # RRC rolloff
            paramTx.Pch_dBm = -2            # power per WDM channel [dBm]
            paramTx.Nch     = 1             # number of WDM channels
            paramTx.Fc      = 193.1e12      # central optical frequency of the WDM spectrum
            paramTx.lw      = lw            # laser linewidth in Hz
            paramTx.freqSpac = 37.5e9       # WDM grid spacing
            paramTx.Nmodes  = 2              # number of signal modes [2 for polarization multiplexed signals]
            paramTx.prgsBar = False
            paramTx.Nbits = int(np.log2(paramTx.M)*1e5) # total number of bits per polarization

            Fs = paramTx.Rs * paramTx.SpS  # simulation sampling rate

            # generate WDM signal
            sigWDM_Tx, symbTx_, paramTx = simpleWDMTx(paramTx)

            SNRdB = snrdB
            sigCh = awgn(sigWDM_Tx, SNRdB, Fs, paramTx.Rs)

            # Receiver

            # parameters
            chIndex  = 0    # index of the channel to be demodulated

            freqGrid = paramTx.freqGrid
            π  = np.pi
            t  = np.arange(0, len(sigCh))*1/Fs 

            symbTx = symbTx_[:,:,chIndex]

            # local oscillator (LO) parameters:
            FO      = 60e6                  # frequency offset
            Δf_lo   = freqGrid[chIndex]+FO  # downshift of the channel to be demodulated

            # generate CW laser LO field
            paramLO = parameters()
            paramLO.P = 10              # power in dBm
            paramLO.lw = lw             # laser linewidth
            paramLO.RIN_var = 0
            paramLO.Ns = len(sigCh)
            paramLO.Fs = Fs

            sigLO = basicLaserModel(paramLO)
            sigLO = sigLO*np.exp(1j*2*π*Δf_lo*t) # add frequency offset

            # polarization multiplexed coherent optical receiver
            sigRx = pdmCoherentReceiver(sigCh, sigLO, θsig = 0)

            # Rx filtering

            # Matched filtering
            if paramTx.pulse == 'nrz':
                pulse = pulseShape('nrz', paramTx.SpS)
            elif paramTx.pulse == 'rrc':
                pulse = pulseShape('rrc', paramTx.SpS, N=paramTx.Ntaps, alpha=paramTx.alphaRRC, Ts=1/paramTx.Rs)
                
            pulse = pnorm(pulse)           
            sigRx = firFilter(pulse, sigRx)

            # decimation
            paramDec = parameters()
            paramDec.SpS_in  = paramTx.SpS
            paramDec.SpS_out = 1
            sigRx = decimate(sigRx, paramDec)

            # compensates for frequency shift
            sigRxFOE, indFO = fourthPower(sigRx, Fs)
            sigRxFOE = pnorm(sigRxFOE)
            
            if alg == 'viterbi':
                # get the channel OSNR in dB
                OSNRdB = 10 * np.log10(SNRdB * paramTx.Rs / 12.5e9)
                # Sum of the laser linewidths of the local oscillator and transmitter.
                deltaV = paramTx.lw + paramLO.lw
                # phase recovery
                sigRxCPR, phi = viterbiCPR(sigRxFOE, deltaV, paramTx.Rs, OSNRdB, N=40)
            
            elif alg == 'viterbiLaplace':
                # phase recovery
                sigRxCPR, phi = laplaceViterbiCPR(sigRxFOE, alpha=0.05, N=40)
            
            
            discard = 20000
            d = pnorm(symbTx)

            ind = np.arange(discard, d.shape[0]-discard)
            
            # Performance metrics
            BER[indAlg,indlw,indSNR], SER[indAlg,indlw,indSNR], SNR[indAlg,indlw,indSNR] = fastBERcalc(sigRxCPR[ind,:][:,0], d[ind,:][:,0], paramTx.M, paramTx.constType)
            
            if indSNR % 2:
                print(f'\nAlgorithm: {alg}\nline width: {int(lw/1e3)} kHz\nSNR Channel: {snrdB} dB \n')
                print(' SER: %.2e,  %.2e'%(SER[indAlg,indlw,indSNR], SER[indAlg,indlw,indSNR]))
                print(' BER: %.2e,  %.2e'%(BER[indAlg,indlw,indSNR], BER[indAlg,indlw,indSNR]))
                print(' SNR: %.2f dB,  %.2f dB'%(SNR[indAlg,indlw,indSNR], SNR[indAlg,indlw,indSNR]))

# save simulation metrics
np.save(path+'ViterbiCPR_lineWidth_SNR', SNR)
np.save(path+'ViterbiCPR_lineWidth_SER', SER)
np.save(path+'ViterbiCPR_lineWidth_BER', BER)
# Out:
# Algorithm: viterbi
# line width: 100 kHz
# SNR Channel: 11 dB
#
#  SER: 7.96e-01,  7.96e-01
#  BER: 2.82e-01,  2.82e-01
#  SNR: 2.39 dB,  2.39 dB
#
# Algorithm: viterbi
# line width: 100 kHz
# SNR Channel: 13 dB
#
#  SER: 7.88e-02,  7.88e-02
#  BER: 2.01e-02,  2.01e-02
#  SNR: 12.99 dB,  12.99 dB
#
# Algorithm: viterbi
# line width: 100 kHz
# SNR Channel: 15 dB
#
#  SER: 2.38e-02,  2.38e-02
#  BER: 5.97e-03,  5.97e-03
#  SNR: 14.85 dB,  14.85 dB
#
# Algorithm: viterbi
# line width: 100 kHz
# SNR Channel: 17 dB
#
#  SER: 3.98e-03,  3.98e-03
#  BER: 1.00e-03,  1.00e-03
#  SNR: 16.73 dB,  16.73 dB
#
# Algorithm: viterbi
# line width: 100 kHz
# SNR Channel: 19 dB
#
#  SER: 6.17e-04,  6.17e-04
#  BER: 1.54e-04,  1.54e-04
#  SNR: 18.54 dB,  18.54 dB
#
# Algorithm: viterbi
# line width: 250 kHz
# SNR Channel: 11 dB
#
#  SER: 1.81e-01,  1.81e-01
#  BER: 4.72e-02,  4.72e-02
#  SNR: 11.07 dB,  11.07 dB
#
# Algorithm: viterbi
# line width: 250 kHz
# SNR Channel: 13 dB
#
#  SER: 8.28e-02,  8.28e-02
#  BER: 2.11e-02,  2.11e-02
#  SNR: 12.91 dB,  12.91 dB
#
# Algorithm: viterbi
# line width: 250 kHz
# SNR Channel: 15 dB
#
#  SER: 2.52e-02,  2.52e-02
#  BER: 6.35e-03,  6.35e-03
#  SNR: 14.81 dB,  14.81 dB
#
# Algorithm: viterbi
# line width: 250 kHz
# SNR Channel: 17 dB
#
#  SER: 5.15e-03,  5.15e-03
#  BER: 1.29e-03,  1.29e-03
#  SNR: 16.64 dB,  16.64 dB
#
# Algorithm: viterbi
# line width: 250 kHz
# SNR Channel: 19 dB
#
#  SER: 6.33e-04,  6.33e-04
#  BER: 1.58e-04,  1.58e-04
#  SNR: 18.43 dB,  18.43 dB
#
# Algorithm: viterbi
# line width: 350 kHz
# SNR Channel: 11 dB
#
#  SER: 1.87e-01,  1.87e-01
#  BER: 4.91e-02,  4.91e-02
#  SNR: 10.96 dB,  10.96 dB
#
# Algorithm: viterbi
# line width: 350 kHz
# SNR Channel: 13 dB
#
#  SER: 8.31e-02,  8.31e-02
#  BER: 2.12e-02,  2.12e-02
#  SNR: 12.94 dB,  12.94 dB
#
# Algorithm: viterbi
# line width: 350 kHz
# SNR Channel: 15 dB
#
#  SER: 2.74e-02,  2.74e-02
#  BER: 6.92e-03,  6.92e-03
#  SNR: 14.76 dB,  14.76 dB
#
# Algorithm: viterbi
# line width: 350 kHz
# SNR Channel: 17 dB
#
#  SER: 5.57e-03,  5.57e-03
#  BER: 1.40e-03,  1.40e-03
#  SNR: 16.58 dB,  16.58 dB
#
# Algorithm: viterbi
# line width: 350 kHz
# SNR Channel: 19 dB
#
#  SER: 1.05e-03,  1.05e-03
#  BER: 2.62e-04,  2.62e-04
#  SNR: 18.28 dB,  18.28 dB
#
# Algorithm: viterbi
# line width: 450 kHz
# SNR Channel: 11 dB
#
#  SER: 3.52e-01,  3.52e-01
#  BER: 1.36e-01,  1.36e-01
#  SNR: 2.14 dB,  2.14 dB
#
# Algorithm: viterbi
# line width: 450 kHz
# SNR Channel: 13 dB
#
#  SER: 8.67e-02,  8.67e-02
#  BER: 2.21e-02,  2.21e-02
#  SNR: 12.88 dB,  12.88 dB
#
# Algorithm: viterbi
# line width: 450 kHz
# SNR Channel: 15 dB
#
#  SER: 2.75e-02,  2.75e-02
#  BER: 6.91e-03,  6.91e-03
#  SNR: 14.71 dB,  14.71 dB
#
# Algorithm: viterbi
# line width: 450 kHz
# SNR Channel: 17 dB
#
#  SER: 2.10e-01,  2.10e-01
#  BER: 8.89e-02,  8.89e-02
#  SNR: 5.42 dB,  5.42 dB
#
# Algorithm: viterbi
# line width: 450 kHz
# SNR Channel: 19 dB
#
#  SER: 1.37e-03,  1.37e-03
#  BER: 3.42e-04,  3.42e-04
#  SNR: 18.12 dB,  18.12 dB
#
# Algorithm: viterbi
# line width: 550 kHz
# SNR Channel: 11 dB
#
#  SER: 8.63e-01,  8.63e-01
#  BER: 4.16e-01,  4.16e-01
#  SNR: -1.99 dB,  -1.99 dB
#
# Algorithm: viterbi
# line width: 550 kHz
# SNR Channel: 13 dB
#
#  SER: 8.87e-02,  8.87e-02
#  BER: 2.26e-02,  2.26e-02
#  SNR: 12.84 dB,  12.84 dB
#
# Algorithm: viterbi
# line width: 550 kHz
# SNR Channel: 15 dB
#
#  SER: 3.49e-01,  3.49e-01
#  BER: 1.32e-01,  1.32e-01
#  SNR: 4.50 dB,  4.50 dB
#
# Algorithm: viterbi
# line width: 550 kHz
# SNR Channel: 17 dB
#
#  SER: 7.30e-03,  7.30e-03
#  BER: 1.83e-03,  1.83e-03
#  SNR: 16.45 dB,  16.45 dB
#
# Algorithm: viterbi
# line width: 550 kHz
# SNR Channel: 19 dB
#
#  SER: 3.39e-01,  3.39e-01
#  BER: 1.34e-01,  1.34e-01
#  SNR: 4.36 dB,  4.36 dB
#
# Algorithm: viterbiLaplace
# line width: 100 kHz
# SNR Channel: 11 dB
#
#  SER: 1.85e-01,  1.85e-01
#  BER: 4.83e-02,  4.83e-02
#  SNR: 11.03 dB,  11.03 dB
#
# Algorithm: viterbiLaplace
# line width: 100 kHz
# SNR Channel: 13 dB
#
#  SER: 8.37e-02,  8.37e-02
#  BER: 2.13e-02,  2.13e-02
#  SNR: 12.90 dB,  12.90 dB
#
# Algorithm: viterbiLaplace
# line width: 100 kHz
# SNR Channel: 15 dB
#
#  SER: 2.60e-02,  2.60e-02
#  BER: 6.53e-03,  6.53e-03
#  SNR: 14.79 dB,  14.79 dB
#
# Algorithm: viterbiLaplace
# line width: 100 kHz
# SNR Channel: 17 dB
#
#  SER: 4.95e-03,  4.95e-03
#  BER: 1.24e-03,  1.24e-03
#  SNR: 16.64 dB,  16.64 dB
#
# Algorithm: viterbiLaplace
# line width: 100 kHz
# SNR Channel: 19 dB
#
#  SER: 7.33e-04,  7.33e-04
#  BER: 1.83e-04,  1.83e-04
#  SNR: 18.45 dB,  18.45 dB
#
# Algorithm: viterbiLaplace
# line width: 250 kHz
# SNR Channel: 11 dB
#
#  SER: 2.29e-01,  2.29e-01
#  BER: 7.22e-02,  7.22e-02
#  SNR: 7.69 dB,  7.69 dB
#
# Algorithm: viterbiLaplace
# line width: 250 kHz
# SNR Channel: 13 dB
#
#  SER: 8.10e-02,  8.10e-02
#  BER: 2.06e-02,  2.06e-02
#  SNR: 12.93 dB,  12.93 dB
#
# Algorithm: viterbiLaplace
# line width: 250 kHz
# SNR Channel: 15 dB
#
#  SER: 2.61e-02,  2.61e-02
#  BER: 6.56e-03,  6.56e-03
#  SNR: 14.79 dB,  14.79 dB
#
# Algorithm: viterbiLaplace
# line width: 250 kHz
# SNR Channel: 17 dB
#
#  SER: 5.02e-03,  5.02e-03
#  BER: 1.25e-03,  1.25e-03
#  SNR: 16.64 dB,  16.64 dB
#
# Algorithm: viterbiLaplace
# line width: 250 kHz
# SNR Channel: 19 dB
#
#  SER: 6.67e-04,  6.67e-04
#  BER: 1.67e-04,  1.67e-04
#  SNR: 18.40 dB,  18.40 dB
#
# Algorithm: viterbiLaplace
# line width: 350 kHz
# SNR Channel: 11 dB
#
#  SER: 1.86e-01,  1.86e-01
#  BER: 4.86e-02,  4.86e-02
#  SNR: 11.02 dB,  11.02 dB
#
# Algorithm: viterbiLaplace
# line width: 350 kHz
# SNR Channel: 13 dB
#
#  SER: 8.35e-02,  8.35e-02
#  BER: 2.13e-02,  2.13e-02
#  SNR: 12.91 dB,  12.91 dB
#
# Algorithm: viterbiLaplace
# line width: 350 kHz
# SNR Channel: 15 dB
#
#  SER: 2.65e-02,  2.65e-02
#  BER: 6.68e-03,  6.68e-03
#  SNR: 14.76 dB,  14.76 dB
#
# Algorithm: viterbiLaplace
# line width: 350 kHz
# SNR Channel: 17 dB
#
#  SER: 5.55e-03,  5.55e-03
#  BER: 1.39e-03,  1.39e-03
#  SNR: 16.57 dB,  16.57 dB
#
# Algorithm: viterbiLaplace
# line width: 350 kHz
# SNR Channel: 19 dB
#
#  SER: 7.83e-04,  7.83e-04
#  BER: 1.96e-04,  1.96e-04
#  SNR: 18.35 dB,  18.35 dB
#
# Algorithm: viterbiLaplace
# line width: 450 kHz
# SNR Channel: 11 dB
#
#  SER: 8.64e-01,  8.64e-01
#  BER: 3.11e-01,  3.11e-01
#  SNR: 2.07 dB,  2.07 dB
#
# Algorithm: viterbiLaplace
# line width: 450 kHz
# SNR Channel: 13 dB
#
#  SER: 8.61e-02,  8.61e-02
#  BER: 2.19e-02,  2.19e-02
#  SNR: 12.86 dB,  12.86 dB
#
# Algorithm: viterbiLaplace
# line width: 450 kHz
# SNR Channel: 15 dB
#
#  SER: 2.59e-02,  2.59e-02
#  BER: 6.50e-03,  6.50e-03
#  SNR: 14.76 dB,  14.76 dB
#
# Algorithm: viterbiLaplace
# line width: 450 kHz
# SNR Channel: 17 dB
#
#  SER: 6.07e-03,  6.07e-03
#  BER: 1.52e-03,  1.52e-03
#  SNR: 16.50 dB,  16.50 dB
#
# Algorithm: viterbiLaplace
# line width: 450 kHz
# SNR Channel: 19 dB
#
#  SER: 1.05e-03,  1.05e-03
#  BER: 2.62e-04,  2.62e-04
#  SNR: 18.23 dB,  18.23 dB
#
# Algorithm: viterbiLaplace
# line width: 550 kHz
# SNR Channel: 11 dB
#
#  SER: 1.89e-01,  1.89e-01
#  BER: 4.93e-02,  4.93e-02
#  SNR: 11.01 dB,  11.01 dB
#
# Algorithm: viterbiLaplace
# line width: 550 kHz
# SNR Channel: 13 dB
#
#  SER: 8.48e-02,  8.48e-02
#  BER: 2.16e-02,  2.16e-02
#  SNR: 12.85 dB,  12.85 dB
#
# Algorithm: viterbiLaplace
# line width: 550 kHz
# SNR Channel: 15 dB
#
#  SER: 2.79e-02,  2.79e-02
#  BER: 7.02e-03,  7.02e-03
#  SNR: 14.72 dB,  14.72 dB
#
# Algorithm: viterbiLaplace
# line width: 550 kHz
# SNR Channel: 17 dB
#
#  SER: 5.90e-03,  5.90e-03
#  BER: 1.48e-03,  1.48e-03
#  SNR: 16.52 dB,  16.52 dB
#
# Algorithm: viterbiLaplace
# line width: 550 kHz
# SNR Channel: 19 dB
#
#  SER: 1.02e-03,  1.02e-03
#  BER: 2.54e-04,  2.54e-04
#  SNR: 18.22 dB,  18.22 dB

# %% [markdown]
# ## Plot 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

X, Y = np.meshgrid(snrValues, lineWidth)

Z1 = BER[0, :, :]   # filtro de máxima verosimilhança
Z2 = BER[1, :, :]   # filtro arbitrário alpha = 0.05

figure = plt.figure(figsize=(10, 5))
axesPlot = plt.axes(projection='3d')

axesPlot.plot_surface(X, Y, np.log10(Z1), cmap='winter', antialiased=False)
axesPlot.plot_surface(X, Y, np.log10(Z2), cmap='summer', antialiased=False)

axesPlot.set_xlabel('SNR (dB)', labelpad=6)
axesPlot.set_ylabel('Line Width (Hz)', labelpad=10)
axesPlot.set_zlabel('BER (dB)');
